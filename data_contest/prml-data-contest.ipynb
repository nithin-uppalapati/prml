# %%
# kaggle competitions download -c prml-data-contest-jan-2021

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/Users/nithinuppalapati/Desktop/IITM_Folder/Semester_VI/CS5691/Assignments/data_contest/prml_song_recog'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))
        print(filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# songs.csv
# save_for_later.csv
# dummy_submission.csv
# test.csv
# song_labels.csv
# train.csv

# %%
os.getcwd()
# Out:
# '/Users/nithinuppalapati/Desktop/IITM_Folder/Semester_VI/CS5691/Assignments/data_contest'

# %%
os.chdir("/Users/nithinuppalapati/Desktop/IITM_Folder/Semester_VI/CS5691/Assignments/data_contest/prml_song_recog")
os.getcwd()
# Out:
# '/Users/nithinuppalapati/Desktop/IITM_Folder/Semester_VI/CS5691/Assignments/data_contest/prml_song_recog'

# %%
train_df = pd.read_csv("train.csv")
print(train_df.shape)
train_df.head()
# Out:
# (710109, 3)
#   customer_id  song_id  score
# 0      O29219     3459      3
# 1      I50343     5326      4
# 2      N42888      236      5
# 3       F5740      724      4
# 4       K4115     8452      5

# %%
train_df["customer_id"].unique()
# Out:
# array(['O29219', 'I50343', 'N42888', ..., 'N14108', 'N29868', 'N32128'],
#       dtype=object)

# %%
train_df["customer_id"].value_counts()
# Out:
# N9668     98
# J15604    98
# F6630     98
# I24143    98
# N10288    97
#           ..
# K51725     6
# M18327     6
# K39865     6
# N50918     6
# F34590     5
# Name: customer_id, Length: 14053, dtype: int64

# %%
song_labels = pd.read_csv("song_labels.csv")
print(song_labels.shape)
song_labels.head()
song_labels["platform_id"].unique()
# Out:
# (999912, 3)
# array(['Q207781', 'S961833', 'X6718608', ..., 'P468070', 'P129510',
#        'V6023056'], dtype=object)

# %%
test_df = pd.read_csv("test.csv")
print(test_df.shape)
test_df.head()
# Out:
# (670681, 2)
#   customer_id  song_id
# 0      J24644     5304
# 1      G29701      123
# 2      M29977       11
# 3      H50752     1445
# 4      J42394      271

# %%
test_df["customer_id"].value_counts()
# Out:
# F6630     99
# J15604    98
# O10509    98
# N9668     98
# I24143    98
#           ..
# N32128    15
# K51725    15
# I40753    15
# K43675    14
# F34590    14
# Name: customer_id, Length: 14053, dtype: int64

# %%
save_df = pd.read_csv("save_for_later.csv")
print(save_df.shape)
save_df.head()
# Out:
# (238880, 2)
#   customer_id  song_id
# 0      F22180     1140
# 1      N34498     1523
# 2      K46875     6918
# 3      L50176     5828
# 4      F13830     3039

# %%
songs_df = pd.read_csv("songs.csv")
print(songs_df.shape)
songs_df.head()

# Mean or Mode imputation for NaN values
# Out:
# (9981, 5)
#    song_id platform_id  released_year language  number_of_comments
# 0     8328   T17332564         2013.0      eng                1936
# 1     8591     T773514         1925.0      eng                 420
# 2      718      U10975         1929.0      eng                5485
# 3     6593      Y12839         1968.0      NaN                 200
# 4      743      Q28881         2002.0    en-US               10411

# %%
# len(songs_df["song_id"].unique())
len(songs_df["platform_id"].unique())
# Out:
# 9981

# %%
song_labels_df = pd.read_csv("song_labels.csv")
print(song_labels_df.shape)
song_labels_df.head()
# Out:
# (999912, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999912 entries, 0 to 999911
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   platform_id  999912 non-null  object
#  1   label_id     999912 non-null  int64
#  2   count        999912 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 22.9+ MB

# %%
train_df.isnull()[:5]
# Out:
#    customer_id  song_id  score
# 0        False    False  False
# 1        False    False  False
# 2        False    False  False
# 3        False    False  False
# 4        False    False  False

# %%
print(np.nonzero(np.array(train_df.isnull())))
print(np.nonzero(np.array(test_df.isnull())))
print(np.nonzero(np.array(save_df.isnull())))
print(np.nonzero(np.array(songs_df.isnull())))
print(np.nonzero(np.array(song_labels_df.isnull())))
# Out:
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([   3,    6,    8, ..., 9913, 9917, 9919]), array([3, 3, 3, ..., 3, 3, 3]))
# (array([], dtype=int64), array([], dtype=int64))

# %%
np.shape(np.nonzero(np.array(songs_df.isnull())))
# Out:
# (2, 1092)

# %%
# MSE for dummy_submission is 1.88016.

############################ Ideas ##########################
# Using vectors for label for a song. Using something like cosine measure for comparision of label of songs.

############################ Below is Testing Area ##########################

# %%
data=[list(train_df["song_id"]),list(train_df["score"])]

def model_naive(data,song_id):
# Out:
#   File "<ipython-input-32-e5a72ddeabd1>", line 6
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
list(train_df["song_id"])
# Out:
# [3459,
#  5326,
#  236,
#  724,
#  8452,
#  230,
#  1247,
#  1119,
#  742,
#  497,
#  98,
#  274,
#  1081,
#  8943,
#  3657,
#  58,
#  8793,
#  12,
#  5827,
#  1443,
#  1693,
#  1831,
#  1742,
#  252,
#  1227,
#  2782,
#  2877,
#  46,
#  3489,
#  247,
#  1621,
#  42,
#  239,
#  8100,
#  2215,
#  18,
#  392,
#  5463,
#  871,
#  4975,
#  2081,
#  508,
#  5057,
#  59,
#  46,
#  1432,
#  38,
#  24,
#  1396,
#  370,
#  9146,
#  104,
#  3673,
#  3642,
#  1972,
#  153,
#  4409,
#  13,
#  269,
#  606,
#  1567,
#  210,
#  1256,
#  137,
#  117,
#  148,
#  2278,
#  149,
#  6387,
#  60,
#  1774,
#  795,
#  2252,
#  4885,
#  5997,
#  5845,
#  5849,
#  3885,
#  1821,
#  2547,
#  82,
#  1961,
#  197,
#  2287,
#  531,
#  163,
#  208,
#  6977,
#  118,
#  613,
#  8962,
#  4466,
#  2337,
#  2177,
#  3869,
#  114,
#  595,
#  164,
#  4038,
#  5850,
#  5836,
#  2123,
#  5002,
#  2463,
#  8543,
#  3,
#  132,
#  81,
#  182,
#  2302,
#  1207,
#  1789,
#  47,
#  3034,
#  120,
#  6201,
#  245,
#  220,
#  446,
# ...
